# %% [markdown]
# <a href="https://colab.research.google.com/github/harshrew19/FORE/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from pathlib import Path

import tensorflow as tf
from tensorflow import keras
from keras import layers

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
PathToFile="/gdrive/MyDrive/BDA DLNLP"

# %%
Path= Path(PathToFile)/ "mobile_price.csv"

# %%
Path
# Out:
# PosixPath('/gdrive/MyDrive/BDA DLNLP/mobile_price.csv')

# %%
X= pd.read_csv(Path)

# %%
X.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
X.shape
# Out:
# (2000, 21)

# %%
y=X.pop('price_range')

# %%
y.head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    1
# Name: price_range, dtype: int64

# %%
y.shape
# Out:
# (2000,)

# %%
X.shape
# Out:
# (2000, 20)

# %%
model=keras.Sequential()

# %%
X.shape[1]
# Out:
# 20

# %%
model.add(layers.Input(X.shape[1]))

# %%
model.add(layers.Dense(4,activation='relu'))

# %%
model.add(layers.Dense(512,activation='sigmoid'))

# %%
model.compile(loss="mse")

# %%
model.fit(X,y, epochs = 800 )
# Out:
# Epoch 1/800
# 63/63 [==============================] - 2s 3ms/step - loss: 2.3971
# Epoch 2/800
# 63/63 [==============================] - 0s 4ms/step - loss: 2.3812
# Epoch 3/800
# 63/63 [==============================] - 0s 4ms/step - loss: 2.3736
# Epoch 4/800
# 63/63 [==============================] - 0s 5ms/step - loss: 2.3723
# Epoch 5/800
# 63/63 [==============================] - 0s 3ms/step - loss: 2.3579
# Epoch 6/800
# 63/63 [==============================] - 0s 2ms/step - loss: 2.3532
# Epoch 7/800
# 63/63 [==============================] - 0s 3ms/step - loss: 2.3494
# Epoch 8/800
# 63/63 [==============================] - 0s 3ms/step - loss: 2.3458
# Epoch 9/800
# 63/63 [==============================] - 0s 3ms/step - loss: 2.3395
# Epoch 10/800
# 63/63 [==============================] - 0s 2ms/step - loss: 2.3349
# Epoch 11/800
# 63/63 [==============================] - 0s 2ms/step - loss: 2.3341
# Epoch 12/800
# ...
